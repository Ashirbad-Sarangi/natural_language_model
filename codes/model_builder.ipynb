# %% [markdown]
# # Notebook to show a sample of implementation of the model_builder class

# %%
import pandas as analytics
from locations import treebank_training_path ,treebank_testing_path
from model_builder import model_builder
# Out:
# 2024-04-16 23:59:17.584368: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-16 23:59:18.442054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df_train = analytics.read_csv(treebank_training_path)
df_test = analytics.read_csv(treebank_testing_path)
print("Train \n",df_train.head(3))
print("\n\nTest \n",df_test.head(3))
# Out:
# Train
#                                                  data
# 0  The new carrier can tote as many as four cups ...
# 1  It 's a classic situation of ads that *T*-75 a...
# 2                                      Fees 1 5\/8 .
#
#
# Test
#                                                  data
# 0  MEDICINE TRANSPLANT : Growth of Japanese trade...
# 1  The government includes money spent * on resid...
# 2  After these payments , about $ 225,000 *U* wil...

# %%
architecture = {
    "model" : None,
    "embedding_dimension" : 2,
    "type_of_cells" : "lstm",
    "number_of_cells" : 1,
    "dropout_percentage" : 0.9,
    "max_epochs" : 1
}
data = {
    "train":df_train[:10],
    "test":df_test[:3]
}

# %%
mb = model_builder(architecture = architecture, data = data)
# Out:
# Extracting training corpus ....  Training corpus extracted successfully !
#
#
# Tokenising the corpus ....
# Total Number of Unique Words [VOCABULARY] : 111
# Corpus be tokenised successfully !
#
#
# Generating input sequence ....  Input sequence generated successfully !
# Optimal Sequence Length : 32
#
#
# Compiling model ....  Modelled compiled successfully with LSTM cells!
# Fit for training ! Training can be done !!!
# 2024-04-16 23:59:19.770067: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
mb.train_model()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.0000e+00 - loss: 4.7091
# Total Training time : 0.00 mins
# Modelled trained successfully !

# %%
mb.test_model()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.0000e+00 - loss: 4.7012
# Loss in testing : 4.701
# Accuracy in testing :0.000
